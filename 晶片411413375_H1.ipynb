# %% [markdown]
# <a href="https://colab.research.google.com/github/glxxx6987-alt/115-1/blob/main/%E6%99%B6%E7%89%87411413375_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello\nhello")
# Out:
# hello
# hello

# %%
print("2026","09",sep=",")
# Out:
# 2026,09

# %%
a=5
b=2.5
c="python"
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
x=20
y=30
temp=x
x=y
y=temp
print(x,y)
# Out:
# 30 20

# %%
t=5
h=5
print(id(t))
print(id(h))
# Out:
# 10446536
# 10446536

# %%
p=50000
rate = 0.015
years = 5

final_amount = p * (1 + rate)**years

print(final_amount)
# Out:
# 53864.20019421873

# %%
x=50000*(1+0.015)**5
print(x)
# Out:
# 53864.20019421873

# %%
a=11
b=12
print("{}\n{}".format(a,b))
# Out:
# 11
# 12

# %%
a=11
b=12
print("{1}\n{0}".format(a,b))
# Out:
# 12
# 11

# %%
a=11
b=12
print("{x}\n{y}".format(x=a,y=b))
# Out:
# 11
# 12

# %%
a=11.123456789
b=22.34567
print("{:.2f}".format(a))
print("{:.3f}".format(b))
print(f"{a}")
# Out:
# 11.12
# 22.346
# 11.123456789

# %%
x=float(input("請輸入數字:"))
print(type(x))
# Out:
# 請輸入數字:123.132
# <class 'float'>

# %%
current = int(input("請輸入目前金幣數量:"))
earning = int(input("請輸入獲得金幣數量:"))

total = current + earning

print(f"任務完成！你現在有{total}枚金幣")
# Out:
# 請輸入目前金幣數量:25
# 請輸入獲得金幣數量:300
# 任務完成！你現在有325枚金幣
