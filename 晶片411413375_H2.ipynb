# %% [markdown]
# <a href="https://colab.research.google.com/github/glxxx6987-alt/115-1/blob/main/%E6%99%B6%E7%89%87411413375_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
current = int(input("請輸入目前金幣數量:"))
earning = int(input("請輸入獲得金幣數量:"))

total = current + earning

print(f"任務完成！你現在有{total}枚金幣")
# Out:
# 請輸入目前金幣數量:300
# 請輸入獲得金幣數量:250
# 任務完成！你現在有550枚金幣
